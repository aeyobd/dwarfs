# %%
import astropy

# %%
from astropy.io import fits

# %%
hdus = fits.open("/Users/daniel/Downloads/cutout-hips.fits")

# %%
hdus.info()
# Out:
# Filename: /Users/daniel/Downloads/cutout-hips.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      25   (4000, 4000, 4)   uint8

# %%
img = hdus[0].data

# %%
import matplotlib.pyplot as plt

# %%
from astropy.visualization import make_lupton_rgb

# %%
import numpy as np

# %%
hdus[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    3 / number of array dimensions
# NAXIS1  =                 4000
# NAXIS2  =                 4000
# NAXIS3  =                    4
# WCSAXES =                    2 / Number of coordinate axes
# CRPIX1  =               2000.0 / Pixel coordinate of reference point
# CRPIX2  =               2000.0 / Pixel coordinate of reference point
# CDELT1  = -0.00012500079328057 / [deg] Coordinate increment at reference point
# CDELT2  =  0.00012500079328058 / [deg] Coordinate increment at reference point
# CUNIT1  = 'deg'                / Units of coordinate increment and value
# CUNIT2  = 'deg'                / Units of coordinate increment and value
# CTYPE1  = 'RA---TAN'           / Right ascension, gnomonic projection
# CTYPE2  = 'DEC--TAN'           / Declination, gnomonic projection
# CRVAL1  =              15.0183 / [deg] Coordinate value at reference point
# CRVAL2  =             -33.7186 / [deg] Coordinate value at reference point
# LONPOLE =                180.0 / [deg] Native longitude of celestial pole
# LATPOLE =             -33.7186 / [deg] Native latitude of celestial pole
# RADESYS = 'ICRS'               / Equatorial coordinate system
# CPYRIGHT= 'DECaM Plane Survey / NOAO - http://decaps.skymaps.info/'
# HISTORY Generated by CDS HiPS2FITS service - See https://alasky.cds.unistra.fr/h
# HISTORY ips-image-services/hips2fits for details
# HISTORY From HiPS  (DES-DR2 ColorIRG)
# HISTORY HiPS created by Boch T. (CDS) - Universite de Strasbourg/CNRS

# %%
plt.imshow(img.transpose((1, 2, 0)), origin="lower")
